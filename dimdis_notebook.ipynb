# %% [markdown]
# # dimdis — Embedding, dimensionality reduction, and clusterability diagnostics
#
# This notebook runs the refactored `dimdis.py` script (which lives in the same folder).
#
# Usage:
# - Edit configuration variables directly in `dimdis.py` (top of the file) or modify them in a cell and `%run -i dimdis.py`.
# - Run the code cell below to execute the script and produce plots + diagnostics.

# %%
# Execute the script in the notebook's kernel.
# Use -i to run in the interactive namespace (so you can set variables here before running if desired).
# %run -i dimdis.py
